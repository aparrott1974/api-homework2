# %%
import pandas as pd
import citipy as cp
import numpy as np
import random
import matplotlib as plt

# %%
import pandas as pd
import numpy as np
lat_list = np.random.randint(-180,high=181,size=(1000,1))  # 1000 random latitudes
lng_list = np.random.randint(-90,high=91,size=(1000,1))  # 1000 random longitudes
lat_list = np.append(lat_list,lng_list,1)
coords = pd.DataFrame(lat_list)
coords.columns=('lat','lng')
coords
# Out:
#      lat  lng
# 0      3   77
# 1    -89  -51
# 2    -34  -72
# 3    -24  -70
# 4    -66   39
# 5    -42   46
# 6   -159   74
# 7    -97  -86
# 8    -23   87
# 9    -75  -40
# 10  -158  -70
# 11   -12  -54
# 12   -78  -22
# 13  -155  -25
# 14  -141   47
# 15  -116  -77
# 16   147   29
# 17   104  -60
# 18   -60  -30
# 19    -6  -76
# 20   124  -73
# 21  -152   41
# 22  -105  -12
# 23  -112   37
# 24   113   17
# 25    55  -79
# 26   117  -31
# 27  -148  -29
# 28   171   64
# 29   118   26
# ..   ...  ...
# 970  162  -67
# 971   18  -16
# 972  114  -90
# 973  -65   85
# 974   29   23
# 975 -104  -34
# 976  126  -68
# 977 -152  -14
# 978  -88  -45
# 979  158  -42
# 980  -77  -87
# 981    6   30
# 982  127   21
# 983 -128  -21
# 984  141   67
# 985   54  -67
# 986   55    8
# 987  -37  -81
# 988  129   16
# 989   72   50
# 990  134   71
# 991 -100  -46
# 992  -10    9
# 993 -121  -42
# 994  175  -30
# 995 -121   22
# 996 -110   77
# 997   48   24
# 998   -6   -6
# 999  125   56
#
# ...

# %%
# anchor coords
# coord=pd.DataFrame({'lat':[random.randrange(-180,180,1)],'lng':[random.randrange(-90,90,1)]})
# coord

# %%
# import pandas as pd
# import numpy as np
# import random
# coord=pd.DataFrame({'lat':[np.random.randint(-180,high=181,size=(10,1))],'lng':[np.random.randint(-90,high=91,size=(10,1))]})
# coord

# %%
# def getcoord(coord):
#     coord

# counter = 0
# while(counter<10):
    # append coord with a new coord pair

# %%
# lat_list=[] #a
# lng_list=[] #b
# counter = 0
# while counter < 10:
#     a, b = process_data(data)
#     lat_list.append(random.randrange(-180,180,1))
#     lng_list.append(random.randrange(-90,90,1))
#     counter+=1
# df=pd.DataFrame({'lat':lat_list,'lng':lng_list})
# df

# %%
# np.random.rand(3,2)

# %%
# np.random_integers(-180,high=180,size=(1,20))
# np.random.random_integers(5, size=(3,2))

# %%
# np.random.randint(-180,high=181,size=(10,1))
